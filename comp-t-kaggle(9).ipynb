# %%
# !pip install torchaudio pandas

import os
import torch
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler, random_split
import pandas as pd
import torchaudio
import numpy as np
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.1.2+cpu)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: torch==2.1.2 in /opt/conda/lib/python3.10/site-packages (from torchaudio) (2.1.2+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (2024.3.1)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.1.2->torchaudio) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.1.2->torchaudio) (1.3.0)
# WARNING: Error parsing requirements for aiohttp: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/aiohttp-3.9.1.dist-info/METADATA'

# %%
# Charger les métadonnées
train_metadata = pd.read_csv('/kaggle/input/birdclef-2024/train_metadata.csv')
taxonomy = pd.read_csv('/kaggle/input/birdclef-2024/eBird_Taxonomy_v2021.csv')
sample_submission = pd.read_csv('/kaggle/input/birdclef-2024/sample_submission.csv')

# Afficher les premières lignes des métadonnées
print(train_metadata.head())
print(taxonomy.head())
print(sample_submission.head())
# Out:
#   primary_label secondary_labels      type  latitude  longitude  \
# 0        asbfly               []  ['call']   39.2297   118.1987
# 1        asbfly               []  ['song']   51.4030   104.6401
# 2        asbfly               []  ['song']   36.3319   127.3555
# 3        asbfly               []  ['call']   21.1697    70.6005
# 4        asbfly               []  ['call']   15.5442    73.7733
#
#       scientific_name             common_name  \
# 0  Muscicapa dauurica  Asian Brown Flycatcher
# 1  Muscicapa dauurica  Asian Brown Flycatcher
# 2  Muscicapa dauurica  Asian Brown Flycatcher
# 3  Muscicapa dauurica  Asian Brown Flycatcher
# 4  Muscicapa dauurica  Asian Brown Flycatcher
#
#                               author  \
# 0                     Matt Slaymaker
# 1                   Magnus Hellström
# 2                      Stuart Fisher
# 3                          vir joshi
# 4  Albert Lastukhin & Sergei Karpeev
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     5.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     2.5
# 2  Creative Commons Attribution-NonCommercial-Sha...     2.5
# 3  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 4  Creative Commons Attribution-NonCommercial-Sha...     4.0
#
#                                  url             filename
# 0  https://www.xeno-canto.org/134896  asbfly/XC134896.ogg
# 1  https://www.xeno-canto.org/164848  asbfly/XC164848.ogg
# 2  https://www.xeno-canto.org/175797  asbfly/XC175797.ogg
# 3  https://www.xeno-canto.org/207738  asbfly/XC207738.ogg
# 4  https://www.xeno-canto.org/209218  asbfly/XC209218.ogg
#    TAXON_ORDER CATEGORY SPECIES_CODE       PRIMARY_COM_NAME  \
# 0            1  species      ostric2         Common Ostrich
# 1            6  species      ostric3         Somali Ostrich
# 2            7    slash       y00934  Common/Somali Ostrich
# 3            8  species      grerhe1           Greater Rhea
# 4           14  species      lesrhe2            Lesser Rhea
#
#                          SCI_NAME            ORDER1  \
# 0                Struthio camelus  Struthioniformes
# 1          Struthio molybdophanes  Struthioniformes
# 2  Struthio camelus/molybdophanes  Struthioniformes
# 3                  Rhea americana        Rheiformes
# 4                    Rhea pennata        Rheiformes
#
#                       FAMILY SPECIES_GROUP REPORT_AS
# 0  Struthionidae (Ostriches)     Ostriches       NaN
# 1  Struthionidae (Ostriches)           NaN       NaN
# 2  Struthionidae (Ostriches)           NaN       NaN
# 3            Rheidae (Rheas)         Rheas       NaN
# 4            Rheidae (Rheas)           NaN       NaN
#                   row_id    asbfly   ashdro1   ashpri1   ashwoo2   asikoe2  \
# 0   soundscape_1446779_5  0.005495  0.005495  0.005495  0.005495  0.005495
# 1  soundscape_1446779_10  0.005495  0.005495  0.005495  0.005495  0.005495
# 2  soundscape_1446779_15  0.005495  0.005495  0.005495  0.005495  0.005495
#
#     asiope1   aspfly1   aspswi1   barfly1  ...   whbwoo2   whcbar1   whiter2  \
# 0  0.005495  0.005495  0.005495  0.005495  ...  0.005495  0.005495  0.005495
# 1  0.005495  0.005495  0.005495  0.005495  ...  0.005495  0.005495  0.005495
# 2  0.005495  0.005495  0.005495  0.005495  ...  0.005495  0.005495  0.005495
#
#      whrmun   whtkin2    woosan   wynlau1   yebbab1   yebbul3   zitcis1
# 0  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 1  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 2  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
#
# [3 rows x 183 columns]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchaudio
import pandas as pd
import os

# Charger les métadonnées pour déterminer le nombre de classes
train_metadata = pd.read_csv('/kaggle/input/birdclef-2024/train_metadata.csv')
num_classes = train_metadata['primary_label'].nunique()

class CNNNetwork(nn.Module):
    def __init__(self, num_classes):
        super(CNNNetwork, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.flatten = nn.Flatten()
        self.dropout = nn.Dropout(0.5)
        self.linear = None  # Placeholder, we will set this later
        self.softmax = nn.Softmax(dim=1)

    def forward(self, input_data):
        x = self.conv1(input_data)
        print("Shape after conv1:", x.shape)
        x = self.conv2(x)
        print("Shape after conv2:", x.shape)
        x = self.conv3(x)
        print("Shape after conv3:", x.shape)
        x = self.conv4(x)
        print("Shape after conv4:", x.shape)
        x = self.flatten(x)
        print("Shape after flatten:", x.shape)
        x = self.dropout(x)

        # Initialize linear layer based on flattened size
        if self.linear is None:
            self.linear = nn.Linear(x.shape[1], num_classes).to(x.device)
        
        logits = self.linear(x)
        predictions = self.softmax(logits)
        return predictions

# %%
import os
import torch
import torchaudio
import pandas as pd
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

# Définissez votre configuration
ANNOTATIONS_FILE = '/kaggle/input/birdclef-2024/train_metadata.csv'
AUDIO_DIR = '/kaggle/input/birdclef-2024/train_audio'
FOLDER_FILTERS = ['barfly1', 'asbfly', 'bkrfla1', 'brakit1', 'categr']
SAMPLE_RATE = 16000
NUM_SAMPLES = 16000
BATCH_SIZE = 32
EPOCHS = 20
LEARNING_RATE = 0.001
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Définir le dataset
class BirdCLEFDataset(Dataset):
    def __init__(self, annotations_file, audio_dir, transformation, target_sample_rate, num_samples, device, folder_filters=None):
        self.annotations = pd.read_csv(annotations_file)
        self.audio_dir = audio_dir
        self.device = device
        self.transformation = transformation.to(self.device)
        self.target_sample_rate = target_sample_rate
        self.num_samples = num_samples
        
        if folder_filters is not None:
            print(f"Applying folder filters: {', '.join(folder_filters)}")
            initial_count = len(self.annotations)
            self.annotations = self.annotations[self.annotations['filename'].str.contains('|'.join(folder_filters))]
            filtered_count = len(self.annotations)
            if filtered_count == 0:
                raise ValueError(f"No files found in folders: {', '.join(folder_filters)}")
            print(f"Filtered dataset from {initial_count} to {filtered_count} samples.")

        self.annotations.reset_index(drop=True, inplace=True)
        self.label_to_index = {label: idx for idx, label in enumerate(self.annotations['primary_label'].unique())}

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, index):
        audio_sample_path = self._get_audio_sample_path(index)
        label = self._get_audio_sample_label(index)
        signal, sr = torchaudio.load(audio_sample_path)
        signal = signal.to(self.device)
        signal = self._resample_if_necessary(signal, sr)
        signal = self._mix_down_if_necessary(signal)
        signal = self._cut_if_necessary(signal)
        signal = self._right_pad_if_necessary(signal)
        signal = self.transformation(signal)
        return signal, label

    def _cut_if_necessary(self, signal):
        if signal.shape[1] > self.num_samples:
            signal = signal[:, :self.num_samples]
        return signal

    def _right_pad_if_necessary(self, signal):
        length_signal = signal.shape[1]
        if length_signal < self.num_samples:
            num_missing_samples = self.num_samples - length_signal
            last_dim_padding = (0, num_missing_samples)
            signal = torch.nn.functional.pad(signal, last_dim_padding)
        return signal

    def _resample_if_necessary(self, signal, sr):
        if sr != self.target_sample_rate:
            resampler = torchaudio.transforms.Resample(sr, self.target_sample_rate).to(self.device)
            signal = resampler(signal)
        return signal

    def _mix_down_if_necessary(self, signal):
        if signal.shape[0] > 1:
            signal = torch.mean(signal, dim=0, keepdim=True)
        return signal

    def _get_audio_sample_path(self, index):
        filename = self.annotations.iloc[index]['filename']
        path = os.path.join(self.audio_dir, filename)
        return path

    def _get_audio_sample_label(self, index):
        label = self.annotations.iloc[index]['primary_label']
        label_index = self.label_to_index[label]
        return label_index

mel_spectrogram = torchaudio.transforms.MelSpectrogram(
    sample_rate=SAMPLE_RATE,
    n_mels=64,
    n_fft=1024,
    hop_length=512
)

# Charger toutes les annotations et filtrer si nécessaire
dataset = BirdCLEFDataset(ANNOTATIONS_FILE, AUDIO_DIR, mel_spectrogram, SAMPLE_RATE, NUM_SAMPLES, device, folder_filters=FOLDER_FILTERS)

# Diviser le dataset en ensemble d'entraînement et de validation
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

class CNNNetwork(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64 * 16 * 8, 128)  # Corrected dimensions here
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.maxpool(x)
        x = self.relu(self.conv2(x))
        x = self.maxpool(x)
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x
# Instancier le modèle
num_classes = len(dataset.label_to_index)
model = CNNNetwork(num_classes=num_classes).to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# Fonction de formation
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 10 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# Fonction de test
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return correct

# Entraîner le modèle
for epoch in range(EPOCHS):
    print(f"Epoch {epoch+1}\n-------------------------------")
    train(train_loader, model, loss_fn, optimizer)
    accuracy = test(val_loader, model, loss_fn)
    print(f"Validation Accuracy: {accuracy:.2f}")

# Sauvegarder le modèle entraîné
torch.save(model.state_dict(), 'birdclef_cnn_model.pth')
# Out:
# Applying folder filters: barfly1, asbfly, bkrfla1, brakit1, categr
# Filtered dataset from 24459 to 408 samples.
# Epoch 1
# -------------------------------
# loss: 2.431548  [    0/  326]
# loss: 1.561733  [   60/  326]
# Test Error:
#  Accuracy: 52.4%, Avg loss: 3.208342
#
# Validation Accuracy: 0.52
# Epoch 2
# -------------------------------
# loss: 2.316254  [    0/  326]
# loss: 0.708998  [   60/  326]
# Test Error:
#  Accuracy: 54.9%, Avg loss: 1.479313
#
# Validation Accuracy: 0.55
# Epoch 3
# -------------------------------
# loss: 0.965161  [    0/  326]
# loss: 0.250756  [   60/  326]
# Test Error:
#  Accuracy: 56.1%, Avg loss: 1.605330
#
# Validation Accuracy: 0.56
# Epoch 4
# -------------------------------
# loss: 1.172156  [    0/  326]
# loss: 0.840605  [   60/  326]
# Test Error:
#  Accuracy: 63.4%, Avg loss: 1.457419
#
# Validation Accuracy: 0.63
# Epoch 5
# -------------------------------
# loss: 0.606099  [    0/  326]
# loss: 0.439121  [   60/  326]
# Test Error:
#  Accuracy: 62.2%, Avg loss: 1.896833
#
# Validation Accuracy: 0.62
# Epoch 6
# -------------------------------
# loss: 0.511577  [    0/  326]
# loss: 1.109510  [   60/  326]
# Test Error:
#  Accuracy: 56.1%, Avg loss: 1.965131
#
# Validation Accuracy: 0.56
# Epoch 7
# -------------------------------
# loss: 0.725082  [    0/  326]
# loss: 0.566434  [   60/  326]
# Test Error:
#  Accuracy: 64.6%, Avg loss: 2.423430
#
# Validation Accuracy: 0.65
# Epoch 8
# -------------------------------
# loss: 0.465711  [    0/  326]
# loss: 0.392201  [   60/  326]
# Test Error:
#  Accuracy: 59.8%, Avg loss: 2.111562
#
# Validation Accuracy: 0.60
# Epoch 9
# -------------------------------
# loss: 0.649369  [    0/  326]
# loss: 0.716891  [   60/  326]
# Test Error:
#  Accuracy: 57.3%, Avg loss: 2.391971
#
# Validation Accuracy: 0.57
# Epoch 10
# -------------------------------
# loss: 0.510523  [    0/  326]
# loss: 1.108748  [   60/  326]
# Test Error:
#  Accuracy: 58.5%, Avg loss: 3.383798
#
# Validation Accuracy: 0.59
# Epoch 11
# -------------------------------
# loss: 0.601826  [    0/  326]
# loss: 0.778233  [   60/  326]
# Test Error:
#  Accuracy: 61.0%, Avg loss: 2.193219
#
# Validation Accuracy: 0.61
# Epoch 12
# -------------------------------
# loss: 0.443301  [    0/  326]
# loss: 0.139409  [   60/  326]
# Test Error:
#  Accuracy: 59.8%, Avg loss: 2.622253
#
# Validation Accuracy: 0.60
# Epoch 13
# -------------------------------
# loss: 0.322421  [    0/  326]
# loss: 0.018109  [   60/  326]
# Test Error:
#  Accuracy: 67.1%, Avg loss: 2.731487
#
# Validation Accuracy: 0.67
# Epoch 14
# -------------------------------
# loss: 0.372367  [    0/  326]
# loss: 0.169630  [   60/  326]
# Test Error:
#  Accuracy: 62.2%, Avg loss: 3.291296
#
# Validation Accuracy: 0.62
# Epoch 15
# -------------------------------
# loss: 0.479671  [    0/  326]
# loss: 0.107225  [   60/  326]
# Test Error:
#  Accuracy: 63.4%, Avg loss: 4.227503
#
# Validation Accuracy: 0.63
# Epoch 16
# -------------------------------
# loss: 0.227528  [    0/  326]
# loss: 0.243480  [   60/  326]
# Test Error:
#  Accuracy: 58.5%, Avg loss: 4.397667
#
# Validation Accuracy: 0.59
# Epoch 17
# -------------------------------
# loss: 0.404740  [    0/  326]
# loss: 0.125112  [   60/  326]
# Test Error:
#  Accuracy: 64.6%, Avg loss: 5.244568
#
# Validation Accuracy: 0.65
# Epoch 18
# -------------------------------
# loss: 0.366132  [    0/  326]
# loss: 0.012103  [   60/  326]
# Test Error:
#  Accuracy: 59.8%, Avg loss: 5.827355
#
# Validation Accuracy: 0.60
# Epoch 19
# -------------------------------
# loss: 0.311478  [    0/  326]
# loss: 0.444417  [   60/  326]
# Test Error:
#  Accuracy: 59.8%, Avg loss: 7.273903
#
# Validation Accuracy: 0.60
# Epoch 20
# -------------------------------
# loss: 0.111380  [    0/  326]
# loss: 0.327458  [   60/  326]
# Test Error:
#  Accuracy: 57.3%, Avg loss: 8.127237
#
# Validation Accuracy: 0.57

# %%
import os
import torch
import torchaudio
import pandas as pd
import torch.nn as nn

class CNNNetwork(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64 * 16 * 8, 128)
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.maxpool(x)
        x = self.relu(self.conv2(x))
        x = self.maxpool(x)
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

def process_audio_file(file_path, transformation, target_sample_rate, num_samples, device):
    signal, sr = torchaudio.load(file_path)
    signal = signal.to(device)
    if sr != target_sample_rate:
        resampler = torchaudio.transforms.Resample(sr, target_sample_rate).to(device)
        signal = resampler(signal)
    if signal.shape[1] > num_samples:
        signal = signal[:, :num_samples]
    elif signal.shape[1] < num_samples:
        num_missing_samples = num_samples - signal.shape[1]
        signal = torch.nn.functional.pad(signal, (0, num_missing_samples))
    signal = transformation(signal)
    return signal

def predict(model, input):
    model.eval()
    with torch.no_grad():
        predictions = model(input)
    return predictions

def main():
    # Charger le fichier d'exemple de soumission pour obtenir les noms de colonnes corrects
    sample_submission_path = '/kaggle/input/birdclef-2024/sample_submission.csv'
    sample_submission = pd.read_csv(sample_submission_path)
    species_columns = sample_submission.columns[1:]

    # Définir les dossiers spécifiques
    FOLDER_FILTERS = ['barfly1', 'asbfly', 'bkrfla1', 'brakit1', 'categr']

    # Charger les métadonnées pour déterminer le nombre de classes
    ANNOTATIONS_FILE = '/kaggle/input/birdclef-2024/train_metadata.csv'
    train_metadata = pd.read_csv(ANNOTATIONS_FILE)
    filtered_metadata = train_metadata[train_metadata['filename'].str.contains('|'.join(FOLDER_FILTERS))]
    num_classes = filtered_metadata['primary_label'].nunique()
    class_mapping = {label: i for i, label in enumerate(filtered_metadata['primary_label'].unique())}
    inv_class_mapping = {v: k for k, v in class_mapping.items()}

    # Charger le modèle
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = CNNNetwork(num_classes=num_classes).to(device)
    
    # Charger l'état du modèle
    state_dict = torch.load('birdclef_cnn_model.pth', map_location=device)
    model.load_state_dict(state_dict)
    model.eval()

    # Transformation
    SAMPLE_RATE = 16000
    NUM_SAMPLES = 16000
    mel_spectrogram = torchaudio.transforms.MelSpectrogram(
        sample_rate=SAMPLE_RATE,
        n_mels=64,
        n_fft=1024,
        hop_length=512
    ).to(device)

    # Initialiser un dictionnaire pour stocker les prédictions
    predictions_dict = {col: [] for col in species_columns}
    predictions_dict['row_id'] = []

    # Fonction sigmoïde pour normaliser les prédictions
    def sigmoid(x):
        return 1 / (1 + torch.exp(-x))

    # Parcourir les dossiers spécifiés et prédire les classes
    audio_dir = '/kaggle/input/birdclef-2024/train_audio'
    end_time_counter = 5  # Initialiser le compteur de temps de fin
    for folder in FOLDER_FILTERS:
        folder_path = os.path.join(audio_dir, folder)
        if os.path.exists(folder_path):
            print(f"Processing folder: {folder}")  # Log the folder being processed
            for root, _, files in os.walk(folder_path):
                for file in files:
                    if file.endswith('.ogg'):
                        file_path = os.path.join(root, file)
                        print(f"Processing file: {file_path}")  # Log the file being processed
                        audio_tensor = process_audio_file(file_path, mel_spectrogram, SAMPLE_RATE, NUM_SAMPLES, device)
                        audio_tensor = audio_tensor.unsqueeze(0)  # Ajouter une dimension pour le batch
                        predictions = predict(model, audio_tensor)
                        
                        # Appliquer la fonction sigmoïde pour normaliser les prédictions
                        predictions = sigmoid(predictions)
                        
                        # Créer une ligne de prédiction par défaut avec des valeurs basses pour toutes les espèces
                        prediction_row = {species: 0.005 for species in species_columns}
                        
                        # Mettre les valeurs prédites pour les espèces correspondantes
                        for i, species in inv_class_mapping.items():
                            prediction_row[species] = predictions[0][i].item()

                        # Créer un identifiant unique pour chaque ligne
                        base_name = os.path.basename(file_path)
                        soundscape_id = base_name.split('.')[0].replace('XC', '')  # Supprimer le préfixe 'XC'
                        row_id = f"soundscape_{soundscape_id}_{end_time_counter}"
                        end_time_counter += 5  # Incrémenter le compteur de temps de fin par 5
                        prediction_row['row_id'] = row_id

                        # Ajouter la ligne au dictionnaire des prédictions
                        for key in predictions_dict:
                            predictions_dict[key].append(prediction_row[key])
        else:
            print(f"Folder {folder} does not exist in the audio directory.")

    # Convertir le dictionnaire en DataFrame
    final_submission = pd.DataFrame(predictions_dict)

    # Réorganiser les colonnes pour correspondre à l'exemple de soumission
    final_submission = final_submission[['row_id'] + list(species_columns)]

    # Enregistrer le fichier de soumission avec des virgules comme séparateurs
    final_submission.to_csv('submission.csv', index=False, sep=',')

    print("Fichier de soumission créé : submission.csv")

if __name__ == "__main__":
    main()
# Out:
# Processing folder: barfly1
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856426.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856473.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC386967.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856487.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856367.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC296410.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856388.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856484.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856020.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856471.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC19576.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856380.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC825806.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856387.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856382.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC548373.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856460.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856365.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856423.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/barfly1/XC856481.ogg
# Processing folder: asbfly
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC342638.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC745831.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC741066.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC629846.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC600171.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC665386.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC267679.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC554430.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC175797.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC629847.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC687954.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC49755.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC677470.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC749597.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC267680.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC164848.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC805713.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC821773.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC347938.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC209218.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC374520.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC647397.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC756431.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC575547.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC505369.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC716727.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC856776.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC724266.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC716740.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC578908.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC610733.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC313835.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC821324.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC347563.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC713503.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC453302.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC825177.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC643642.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC207738.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC687953.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC341611.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC589132.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC396237.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC528852.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC830258.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC329259.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC405069.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC778686.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC610735.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC341612.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC834959.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC712207.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC499134.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC530877.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC305518.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC309402.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC756617.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC713467.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC770506.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC741067.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC396238.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC267681.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC441145.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC716692.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC267683.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC858110.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC716737.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC741062.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC818340.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC484489.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC785503.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC134896.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC827640.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC508268.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC770507.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC842684.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC464609.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC716738.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC833987.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC342037.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC778717.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC596043.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC775904.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC412228.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC718355.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC399102.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC756532.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC267682.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC837545.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC291450.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC716486.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC839572.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC842686.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC610734.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC846616.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC412227.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC760532.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC684073.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC578909.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC209219.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC312456.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC376509.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC767510.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC687955.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/asbfly/XC724148.ogg
# Processing folder: bkrfla1
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC19591.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC537852.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC644026.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC453733.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC561070.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC665947.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC612026.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC795699.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC142801.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC469352.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC196734.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC209205.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC116440.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC267360.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC323802.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC208903.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC572365.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC240264.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC795413.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC209024.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC324155.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC196960.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC416112.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC419783.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC552421.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC209206.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC255437.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC754340.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/bkrfla1/XC283189.ogg
# Processing folder: brakit1
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC702713.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC197756.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC736313.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC196654.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC151328.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC209216.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC827537.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC32856.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC246760.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC684723.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC188232.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC815593.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC575565.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC825161.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC399255.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC163896.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC163895.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC208282.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC743675.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC665742.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC598947.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC190244.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC208281.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC575563.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC215852.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC685003.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC663573.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC456866.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC430881.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC32855.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC663576.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC663577.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC284777.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC208283.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC575564.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC204374.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC537471.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC663575.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC578793.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC386935.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC353968.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC644542.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC665743.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/brakit1/XC651717.ogg
# Processing folder: categr
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC410973.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC713106.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC361546.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC246911.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC57417.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC857912.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC787914.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC361547.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC304256.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC322747.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC353849.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC368935.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC800075.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC829008.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC218727.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC800987.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC517417.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC311860.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC298147.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC800225.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC478387.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC800226.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC57418.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC371472.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC372953.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC210378.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC339758.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC136312.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC289295.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC669289.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC26215.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC838627.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC458426.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC623267.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC800985.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC514784.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC288324.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC131326.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC304258.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC304251.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC527812.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC368934.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC452088.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC438523.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC713117.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC304255.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC451817.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC679852.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC713118.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC734226.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC57416.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC747220.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC192966.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC774059.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC361553.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC501019.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC478435.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC157743.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC829325.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC194457.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC452565.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC45475.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC143599.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC45477.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC117115.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC288325.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC353850.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC197438.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC45472.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC124271.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC713110.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC274826.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC611986.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC787338.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC129098.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC757065.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC734540.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC363098.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC423135.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC143597.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC694719.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC148199.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC629216.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC748802.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC787918.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC398976.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC368933.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC478434.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC838626.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC45474.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC838625.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC267153.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC610382.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC143598.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC315439.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC687763.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC783037.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC747776.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC361552.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC113766.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC453176.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC576956.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC321214.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC517403.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC797583.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC304252.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC838331.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC192968.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC361548.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC773428.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC794808.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC769887.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC328546.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC674737.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC803079.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC713127.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC773427.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC379067.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC783036.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC613482.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC57415.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC811818.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC422247.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC298914.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC624047.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC246912.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC282494.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC774052.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC411144.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC520659.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC353848.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC692762.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC353847.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC297698.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC139952.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC451682.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC576962.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC418997.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC834409.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC350629.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC791098.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC328548.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC826170.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC352659.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC313748.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC451681.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC361549.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC389992.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC713124.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC329275.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC800224.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC828995.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC746522.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC814122.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC143602.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC414792.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC304257.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC174527.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC361551.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC756285.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC713098.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC192969.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC585965.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC125870.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC393573.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC838629.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC857111.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC666212.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC734223.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC794287.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC463749.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC403813.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC162141.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC787916.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC844711.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC776968.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC713096.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC770139.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC257319.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC45473.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC682210.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC327832.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC368932.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC704006.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC756290.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC527808.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC45476.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC143596.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC603551.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC845737.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC57419.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC274824.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC369827.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC108820.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC485246.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC146066.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC196079.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC740802.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC352660.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC139953.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC838628.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC196080.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC418722.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC332570.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC838330.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC143600.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC838624.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC756293.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC196081.ogg
# Processing file: /kaggle/input/birdclef-2024/train_audio/categr/XC304253.ogg
# Fichier de soumission créé : submission.csv
